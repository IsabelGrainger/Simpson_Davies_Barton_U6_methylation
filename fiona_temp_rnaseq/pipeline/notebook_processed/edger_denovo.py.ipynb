# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/cluster/ggs_lab/mtparker/.conda/envs/snakemake/lib/python3.7/site-packages', '/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x03csnakemake.script\nSnakemake\nq\x00)\x81q\x01}q\x02(X\x05\x00\x00\x00inputq\x03csnakemake.io\nInputFiles\nq\x04)\x81q\x05(X)\x00\x00\x00quantification/denovo/fio1_20c_3/quant.sfq\x06X)\x00\x00\x00quantification/denovo/col0_28c_3/quant.sfq\x07X)\x00\x00\x00quantification/denovo/col0_20c_2/quant.sfq\x08X)\x00\x00\x00quantification/denovo/col0_12c_1/quant.sfq\tX)\x00\x00\x00quantification/denovo/fio1_20c_1/quant.sfq\nX)\x00\x00\x00quantification/denovo/fio1_28c_4/quant.sfq\x0bX)\x00\x00\x00quantification/denovo/fio1_28c_2/quant.sfq\x0cX)\x00\x00\x00quantification/denovo/col0_28c_4/quant.sfq\rX)\x00\x00\x00quantification/denovo/fio1_04c_4/quant.sfq\x0eX)\x00\x00\x00quantification/denovo/col0_28c_5/quant.sfq\x0fX)\x00\x00\x00quantification/denovo/fio1_28c_1/quant.sfq\x10X)\x00\x00\x00quantification/denovo/fio1_12c_6/quant.sfq\x11X)\x00\x00\x00quantification/denovo/fio1_12c_1/quant.sfq\x12X)\x00\x00\x00quantification/denovo/fio1_28c_3/quant.sfq\x13X)\x00\x00\x00quantification/denovo/fio1_12c_5/quant.sfq\x14X)\x00\x00\x00quantification/denovo/col0_28c_6/quant.sfq\x15X)\x00\x00\x00quantification/denovo/fio1_20c_2/quant.sfq\x16X)\x00\x00\x00quantification/denovo/col0_20c_3/quant.sfq\x17X)\x00\x00\x00quantification/denovo/col0_12c_4/quant.sfq\x18X)\x00\x00\x00quantification/denovo/col0_12c_6/quant.sfq\x19X)\x00\x00\x00quantification/denovo/fio1_28c_6/quant.sfq\x1aX)\x00\x00\x00quantification/denovo/col0_20c_5/quant.sfq\x1bX)\x00\x00\x00quantification/denovo/fio1_04c_5/quant.sfq\x1cX)\x00\x00\x00quantification/denovo/fio1_12c_4/quant.sfq\x1dX)\x00\x00\x00quantification/denovo/col0_04c_2/quant.sfq\x1eX)\x00\x00\x00quantification/denovo/fio1_04c_3/quant.sfq\x1fX)\x00\x00\x00quantification/denovo/col0_28c_2/quant.sfq X)\x00\x00\x00quantification/denovo/col0_12c_5/quant.sfq!X)\x00\x00\x00quantification/denovo/fio1_04c_6/quant.sfq"X)\x00\x00\x00quantification/denovo/col0_20c_4/quant.sfq#X)\x00\x00\x00quantification/denovo/fio1_20c_6/quant.sfq$X)\x00\x00\x00quantification/denovo/col0_12c_2/quant.sfq%X)\x00\x00\x00quantification/denovo/fio1_04c_2/quant.sfq&X)\x00\x00\x00quantification/denovo/col0_04c_4/quant.sfq\'X)\x00\x00\x00quantification/denovo/fio1_12c_2/quant.sfq(X)\x00\x00\x00quantification/denovo/col0_04c_3/quant.sfq)X)\x00\x00\x00quantification/denovo/fio1_20c_4/quant.sfq*X)\x00\x00\x00quantification/denovo/col0_04c_1/quant.sfq+X)\x00\x00\x00quantification/denovo/fio1_28c_5/quant.sfq,X)\x00\x00\x00quantification/denovo/fio1_04c_1/quant.sfq-X)\x00\x00\x00quantification/denovo/col0_20c_6/quant.sfq.X)\x00\x00\x00quantification/denovo/col0_04c_6/quant.sfq/X)\x00\x00\x00quantification/denovo/col0_12c_3/quant.sfq0X)\x00\x00\x00quantification/denovo/col0_28c_1/quant.sfq1X)\x00\x00\x00quantification/denovo/fio1_20c_5/quant.sfq2X)\x00\x00\x00quantification/denovo/col0_04c_5/quant.sfq3X)\x00\x00\x00quantification/denovo/col0_20c_1/quant.sfq4X)\x00\x00\x00quantification/denovo/fio1_12c_3/quant.sfq5e}q6(X\x06\x00\x00\x00_namesq7}q8X\r\x00\x00\x00salmon_quantsq9K\x00K0\x86q:sX\x12\x00\x00\x00_allowed_overridesq;]q<(X\x05\x00\x00\x00indexq=X\x04\x00\x00\x00sortq>eh=cfunctools\npartial\nq?cbuiltins\ngetattr\nq@csnakemake.io\nNamedlist\nqAX\x0f\x00\x00\x00_used_attributeqB\x86qCRqD\x85qERqF(hD)}qGX\x05\x00\x00\x00_nameqHh=sNtqIbh>h?hD\x85qJRqK(hD)}qLhHh>sNtqMbh9hA)\x81qN(h\x06h\x07h\x08h\th\nh\x0bh\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5e}qO(h7}qPh;]qQ(h=h>eh=h?hD\x85qRRqS(hD)}qThHh=sNtqUbh>h?hD\x85qVRqW(hD)}qXhHh>sNtqYbububX\x06\x00\x00\x00outputqZcsnakemake.io\nOutputFiles\nq[)\x81q\\(X\x1d\x00\x00\x00quantification/denovo/cpm.tsvq]X\x1d\x00\x00\x00quantification/denovo/dge.tsvq^X\x1a\x00\x00\x00figures/dge/denovo/pca.svgq_X&\x00\x00\x00figures/dge/denovo/fio1_expression.svgq`X&\x00\x00\x00figures/dge/denovo/mafs_expression.svgqaX*\x00\x00\x00figures/dge/denovo/ft_genes_expression.svgqbe}qc(h7}qd(X\x03\x00\x00\x00cpmqeK\x00N\x86qfX\x03\x00\x00\x00dgeqgK\x01N\x86qhX\x08\x00\x00\x00pca_plotqiK\x02N\x86qjX\t\x00\x00\x00fio1_plotqkK\x03N\x86qlX\t\x00\x00\x00mafs_plotqmK\x04N\x86qnX\x07\x00\x00\x00ft_plotqoK\x05N\x86qpuh;]qq(h=h>eh=h?hD\x85qrRqs(hD)}qthHh=sNtqubh>h?hD\x85qvRqw(hD)}qxhHh>sNtqybheh]hgh^hih_hkh`hmhahohbubX\x06\x00\x00\x00paramsqzcsnakemake.io\nParams\nq{)\x81q|}q}(h7}q~h;]q\x7f(h=h>eh=h?hD\x85q\x80Rq\x81(hD)}q\x82hHh=sNtq\x83bh>h?hD\x85q\x84Rq\x85(hD)}q\x86hHh>sNtq\x87bubX\t\x00\x00\x00wildcardsq\x88csnakemake.io\nWildcards\nq\x89)\x81q\x8aX\x06\x00\x00\x00denovoq\x8ba}q\x8c(h7}q\x8dX\x08\x00\x00\x00ref_typeq\x8eK\x00N\x86q\x8fsh;]q\x90(h=h>eh=h?hD\x85q\x91Rq\x92(hD)}q\x93hHh=sNtq\x94bh>h?hD\x85q\x95Rq\x96(hD)}q\x97hHh>sNtq\x98bX\x08\x00\x00\x00ref_typeq\x99h\x8bubX\x07\x00\x00\x00threadsq\x9aK\x01X\t\x00\x00\x00resourcesq\x9bcsnakemake.io\nResources\nq\x9c)\x81q\x9d(K\x01K\x01e}q\x9e(h7}q\x9f(X\x06\x00\x00\x00_coresq\xa0K\x00N\x86q\xa1X\x06\x00\x00\x00_nodesq\xa2K\x01N\x86q\xa3uh;]q\xa4(h=h>eh=h?hD\x85q\xa5Rq\xa6(hD)}q\xa7hHh=sNtq\xa8bh>h?hD\x85q\xa9Rq\xaa(hD)}q\xabhHh>sNtq\xacbh\xa0K\x01h\xa2K\x01ubX\x03\x00\x00\x00logq\xadcsnakemake.io\nLog\nq\xae)\x81q\xafX(\x00\x00\x00notebook_processed/edger_denovo.py.ipynbq\xb0a}q\xb1(h7}q\xb2X\x08\x00\x00\x00notebookq\xb3K\x00N\x86q\xb4sh;]q\xb5(h=h>eh=h?hD\x85q\xb6Rq\xb7(hD)}q\xb8hHh=sNtq\xb9bh>h?hD\x85q\xbaRq\xbb(hD)}q\xbchHh>sNtq\xbdbh\xb3h\xb0ubX\x06\x00\x00\x00configq\xbe}q\xbf(X\x0f\x00\x00\x00genome_fasta_fnq\xc0X:\x00\x00\x00../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.faq\xc1X\x0c\x00\x00\x00annot_gtf_fnq\xc2XA\x00\x00\x00../annotations/Araport11_GFF3_genes_transposons.201606.no_chr.gtfq\xc3X\x16\x00\x00\x00transcriptome_fasta_fnq\xc4]q\xc5(X0\x00\x00\x00../annotations/Araport11_genes.201606.cdna.fastaq\xc6X5\x00\x00\x00../annotations/Araport11_non_coding.201606.cdna.fastaq\xc7eX\x11\x00\x00\x00proteome_fasta_fnq\xc8X4\x00\x00\x00../annotations/Araport11_genes.201606.pep.repr.fastaq\xc9X\x14\x00\x00\x00fastq_screen_genomesq\xca}q\xcb(X\t\x00\x00\x00athalianaq\xccX:\x00\x00\x00../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.faq\xcdX\x08\x00\x00\x00hsapiensq\xceX=\x00\x00\x00../annotations/Homo_sapiens.GRCh38.dna_sm.primary_assembly.faq\xcfX\x07\x00\x00\x00at_rrnaq\xd0X\x1c\x00\x00\x00../annotations/arath_rrna.faq\xd1X\x05\x00\x00\x00ecoliq\xd2X"\x00\x00\x00../annotations/ecoli_k12_mg1655.faq\xd3uX\x11\x00\x00\x00suppa_comparisonsq\xd4]q\xd5(X\x14\x00\x00\x00col0_04c_vs_col0_20cq\xd6X\x14\x00\x00\x00col0_12c_vs_col0_20cq\xd7X\x14\x00\x00\x00col0_28c_vs_col0_20cq\xd8X\x14\x00\x00\x00fio1_04c_vs_fio1_20cq\xd9X\x14\x00\x00\x00fio1_12c_vs_fio1_20cq\xdaX\x14\x00\x00\x00fio1_28c_vs_fio1_20cq\xdbX\x14\x00\x00\x00fio1_04c_vs_col0_04cq\xdcX\x14\x00\x00\x00fio1_12c_vs_col0_12cq\xddX\x14\x00\x00\x00fio1_20c_vs_col0_20cq\xdeX\x14\x00\x00\x00fio1_28c_vs_col0_28cq\xdfeuX\x04\x00\x00\x00ruleq\xe0X\t\x00\x00\x00run_edgerq\xe1X\x0f\x00\x00\x00bench_iterationq\xe2NX\t\x00\x00\x00scriptdirq\xe3XQ\x00\x00\x00/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/rules/notebook_templatesq\xe4ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir('/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
from sklearn.decomposition import PCA

# %load_ext rpy2.ipython
from rpy2 import robjects as robj
from rpy2.robjects.packages import importr
from rpy2.robjects.conversion import localconverter
from rpy2.rinterface import RRuntimeWarning

from rpy2.robjects import pandas2ri

warnings.filterwarnings("ignore", category=RRuntimeWarning)

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1.2, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()
# Out:
# /cluster/ggs_lab/mtparker/.conda/envs/nb_rpy2/lib/python3.6/site-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %%
sample_fns = [str(fn) for fn in snakemake.input.salmon_quants]
sample_ids = [fn.split('/')[-2] for fn in sample_fns]
print(sample_ids)
# Out:
# ['fio1_20c_3', 'col0_28c_3', 'col0_20c_2', 'col0_12c_1', 'fio1_20c_1', 'fio1_28c_4', 'fio1_28c_2', 'col0_28c_4', 'fio1_04c_4', 'col0_28c_5', 'fio1_28c_1', 'fio1_12c_6', 'fio1_12c_1', 'fio1_28c_3', 'fio1_12c_5', 'col0_28c_6', 'fio1_20c_2', 'col0_20c_3', 'col0_12c_4', 'col0_12c_6', 'fio1_28c_6', 'col0_20c_5', 'fio1_04c_5', 'fio1_12c_4', 'col0_04c_2', 'fio1_04c_3', 'col0_28c_2', 'col0_12c_5', 'fio1_04c_6', 'col0_20c_4', 'fio1_20c_6', 'col0_12c_2', 'fio1_04c_2', 'col0_04c_4', 'fio1_12c_2', 'col0_04c_3', 'fio1_20c_4', 'col0_04c_1', 'fio1_28c_5', 'fio1_04c_1', 'col0_20c_6', 'col0_04c_6', 'col0_12c_3', 'col0_28c_1', 'fio1_20c_5', 'col0_04c_5', 'col0_20c_1', 'fio1_12c_3']

# %%
rstats = importr('stats')
rbase = importr('base')
edgeR = importr('edgeR')
limma = importr('limma')
tximport = importr('tximport')


def to_r_dataframe(pd_df):
    with localconverter(robj.default_converter + pandas2ri.converter):
        r_from_pd_df = robj.conversion.py2rpy(pd_df)
    return r_from_pd_df


def to_r_matrix(pd_df):
    r_df  = to_r_dataframe(pd_df)
    return rbase.as_matrix(r_df)


def to_pd_dataframe(sobj):
    with localconverter(robj.default_converter + pandas2ri.converter):
        pd_from_r_df = robj.conversion.rpy2py(robj.r('as.data.frame')(sobj))
    return pd_from_r_df


def get_sample_ids(conds, reps):
    sample_names = np.repeat(conds, reps).tolist()
    sample_nos = np.concatenate([np.arange(n) + 1 for n in reps])
    sample_ids = [f'{sn}_{n}' for sn, n in zip(sample_names, sample_nos)]
    return sample_names, sample_ids


def read_salmon(fn, sample_ids):
    tx2gene = pd.read_table(fn[0], usecols=[0], names=['TXNAME'], header=0)
    tx2gene['GENENAME'] = tx2gene.TXNAME.str.split('[._]', expand=True)[0]
    tx2gene = to_r_dataframe(tx2gene)
    fn = robj.StrVector(np.array(fn))
    fn.names = sample_ids
    salmon_data = tximport.tximport(
        fn, type='salmon', tx2gene=tx2gene, dropInfReps=True)
    return salmon_data.rx2('counts'), salmon_data.rx2('length')


def create_dgelist(counts, group):
    _create_dgelist = robj.r('''
        function (counts, group) {
            y <- edgeR::DGEList(counts, group=group)
            y <- calcNormFactors(y, method='TMM')
            keep <- filterByExpr(y, group=group)
            y <- y[keep, keep.lib.sizes=TRUE]
            return (y)
        }
    ''')
    group = robj.FactorVector(group)
    dgelist = _create_dgelist(counts, group)
    dgelist = edgeR.estimateDisp(dgelist)
    return dgelist


def get_normalised_counts(dgelist):
    cpm = edgeR.cpm(dgelist, log=True)
    cpm_df = to_pd_dataframe(cpm)
    return cpm_df


def model_matrix(exprs, dgelist, use_group=False):
    if exprs is None:
        exprs = robj.NULL
    _model_matrix = robj.r('''
        function (exprs, dgelist, use_group) {
            if (use_group) {
                design <- stats::model.matrix(~0 + dgelist$samples$group)
                colnames(design) <- levels(dgelist$samples$group)
                rownames(design) <- rownames(dgelist$samples)
            } else {
                design <- stats::model.matrix(exprs, data=dgelist$samples)
            }
            colnames(design) <- gsub(':', '_x_', colnames(design))
            return (design)
        }
    ''')
    design = _model_matrix(
        robj.Formula(exprs), dgelist, use_group
    )
    return design


def get_dgelist_and_cpm(salmon_fns, sample_ids, samples_col_names):
    group = [sn.rsplit('_', 1)[0] for sn in sample_ids]
    counts, length = read_salmon(salmon_fns, sample_ids)
    dgelist = create_dgelist(counts, group)
    return dgelist, get_normalised_counts(dgelist)


def cfit_to_df(cfit):
    tt = edgeR.topTags(cfit, n=np.inf, adjust_method='BH', sort_by='none')
    return to_pd_dataframe(tt)


def run_edgr_de(dgelist, design_exprs=None, use_group=False, **contrasts):
    if design_exprs is None and not use_group:
        raise ValueError()
    design = model_matrix(design_exprs, dgelist, use_group=use_group)
    fit = edgeR.glmFit(dgelist, design)
    coef = limma.makeContrasts(**contrasts, levels=design)
    cfit = edgeR.glmLRT(fit, contrast=coef)
    return cfit_to_df(cfit), coef, design

# %% [markdown]
# ## Gene expression analysis

# %%
dgelist, cpm = get_dgelist_and_cpm(sample_fns, sample_ids, ['geno', 'temp'])
# Out:
# R[write to console]: reading in files with read_tsv
#
# R[write to console]: 1
# R[write to console]: 2
# R[write to console]: 3
# R[write to console]: 4
# R[write to console]: 5
# R[write to console]: 6
# R[write to console]: 7
# R[write to console]: 8
# R[write to console]: 9
# R[write to console]: 10
# R[write to console]: 11
# R[write to console]: 12
# R[write to console]: 13
# R[write to console]: 14
# R[write to console]: 15
# R[write to console]: 16
# R[write to console]: 17
# R[write to console]: 18
# R[write to console]: 19
# R[write to console]: 20
# R[write to console]: 21
# R[write to console]: 22
# R[write to console]: 23
# R[write to console]: 24
# R[write to console]: 25
# R[write to console]: 26
# R[write to console]: 27
# R[write to console]: 28
# R[write to console]: 29
# R[write to console]: 30
# R[write to console]: 31
# R[write to console]: 32
# R[write to console]: 33
# R[write to console]: 34
# R[write to console]: 35
# R[write to console]: 36
# ...

# %%
cpm.to_csv(snakemake.output.cpm)
cpm.head()
# Out:
#            fio1_20c_3  col0_28c_3  col0_20c_2  col0_12c_1  fio1_20c_1  \
# AT1G01010    3.795118    3.513347    3.700634    3.763457    3.266469
# AT1G01020    3.376623    3.667250    3.553591    3.301144    3.361253
# AT1G01030    0.739971    0.613878    0.761677    1.097411    0.808116
# AT1G01040    5.469119    5.529415    5.588843    5.698047    5.144923
# AT1G01050    5.088315    5.230671    5.118208    5.206225    5.085378
#
#            fio1_28c_4  fio1_28c_2  col0_28c_4  fio1_04c_4  col0_28c_5  ...  \
# AT1G01010    3.257858    3.303414    3.453579    4.031305    3.360906  ...
# AT1G01020    3.490266    4.337144    3.884051    3.111249    3.691967  ...
# AT1G01030    0.891383    0.809562    0.697576    1.495534    0.605657  ...
# AT1G01040    5.390327    4.450382    5.279306    5.766985    4.542957  ...
# AT1G01050    5.146811    5.255568    5.345080    4.966353    5.533217  ...
#
#            fio1_28c_5  fio1_04c_1  col0_20c_6  col0_04c_6  col0_12c_3  \
# ...

# %%
comps = PCA(n_components=2).fit_transform(cpm.T)
comps = pd.DataFrame(comps, columns=['Component 1', 'Component 2'], index=cpm.columns)
comps['Genotype'] = comps.index.to_series().str.split('_', expand=True)[0].map({'col0': 'Col-0', 'fio1': 'fio1-3'})
comps['Temperature'] = comps.index.to_series().str.split('_', expand=True)[1].str[:-1].str.lstrip('0')

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sns.scatterplot(x='Component 1', y='Component 2', hue='Temperature', style='Genotype', data=comps)
ax.legend(loc=5, ncol=3)
plt.savefig(snakemake.output.pca_plot)
plt.show()

# %%
fio1_vs_col0_de, coef, design = run_edgr_de(
    dgelist,
    use_group=True,
    fio1_vs_col0='(fio1_04c + fio1_12c + fio1_20c + fio1_28c) / 4 - (col0_04c + col0_12c + col0_20c + col0_28c) / 4',
    very_low_temp='col0_04c - (col0_12c + col0_20c) / 2',
    low_temp='(col0_04c + col0_12c) / 2 - col0_20c',
    high_temp='col0_28c - col0_20c',
    extreme_temp = '(col0_04c + col0_28c) / 2 - (col0_12c + col0_20c) / 2',
    fio1_low_temp='(fio1_04c - col0_04c) - (fio1_20c - col0_20c)',
    fio1_high_temp='(fio1_28c - col0_28c) - (fio1_20c - col0_20c)',
)

# %%
fio1_vs_col0_de.to_csv(snakemake.output.dge)
fio1_vs_col0_de.head()
# Out:
#            logFC.fio1_vs_col0  logFC.very_low_temp  logFC.low_temp  \
# AT1G01010           -0.167450             0.076075        0.084820
# AT1G01020           -0.053607            -0.195098       -0.210178
# AT1G01030            0.190044             0.149569        0.401838
# AT1G01040           -0.086596             0.181179        0.188194
# AT1G01050           -0.136271            -0.004066       -0.122965
#
#            logFC.high_temp  logFC.extreme_temp  logFC.fio1_low_temp  \
# AT1G01010        -0.221401           -0.088257             0.269955
# AT1G01020         0.203555            0.041772            -0.052369
# AT1G01030        -0.064914           -0.066690             0.119794
# AT1G01040        -0.300121           -0.092006             0.040400
# AT1G01050         0.129850            0.103202             0.007519
#
#            logFC.fio1_high_temp    logCPM         LR        PValue  \
# AT1G01010             -0.005533  3.682725  69.528432  5.108573e-13
# ...

# %% [markdown]
# ## Individual gene plots

# %%
def plot_single_gene(gene_id, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 5))
    sns.stripplot(
        x='temp',
        y='cpm',
        hue='geno',
        data=cpm_melt.query(f'index=="{gene_id}"'),
        jitter=0.3,
        dodge=True,
        hue_order=['col0', 'fio1'],
        ax=ax
    )
    sns.boxplot(
        x='temp',
        y='cpm',
        hue='geno',
        data=cpm_melt.query(f'index=="{gene_id}"'),
        color='#eeeeee',
        ax=ax,
        showfliers=False,
        hue_order=['col0', 'fio1'],
    )
    ax.legend_.remove()
    h1 = ax.scatter([], [], color=pal[0], label='Col-0')
    h2 = ax.scatter([], [], color=pal[1], label='fio1-3')
    ax.legend([h1, h2], ['Col-0', 'fio1-3'])
    ax.set_xlabel('Temperature (°C)')
    ax.set_ylabel('Log2 counts per million')
    if title is None:
        ax.set_title(gene_id)
    else:
        ax.set_title(title)
    return ax


cpm_melt = pd.melt(
    cpm.reset_index(),
    id_vars='index',
    value_vars=cpm.columns,
    value_name='cpm',
    var_name='sample_id'
)
cpm_melt = cpm_melt.join(
    cpm_melt.sample_id.str.split('_', expand=True).rename(columns={0:'geno', 1:'temp', 2:'rep'})
)
cpm_melt['temp'] = cpm_melt.temp.str.strip('c').astype(int)
cpm_melt.head()
# Out:
#        index   sample_id       cpm  geno  temp rep
# 0  AT1G01010  fio1_20c_3  3.795118  fio1    20   3
# 1  AT1G01020  fio1_20c_3  3.376623  fio1    20   3
# 2  AT1G01030  fio1_20c_3  0.739971  fio1    20   3
# 3  AT1G01040  fio1_20c_3  5.469119  fio1    20   3
# 4  AT1G01050  fio1_20c_3  5.088315  fio1    20   3

# %% [markdown]
# What is the expression of FIO1 in the *fio1-3* mutant?

# %%
plot_single_gene('AT2G21070', title='FIO1')
plt.savefig(snakemake.output.fio1_plot)
plt.show()

# %% [markdown]
# Expression of flowering time related genes in the *fio1-3* mutant

# %%
fig, axes = plt.subplots(figsize=(15, 10), ncols=3, nrows=2)
for gene_id, gene_name, ax in zip(
    ['AT1G77080', 'AT5G65050', 'AT5G65060', 'AT5G65070', 'AT5G65080',],
    ['FLM', 'MAF2', 'MAF3', 'MAF4', 'MAF5'],
    axes.ravel()):
    plot_single_gene(gene_id, ax, title=gene_name)
plt.tight_layout()
plt.savefig(snakemake.output.mafs_plot)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(15, 10), ncols=3, nrows=2)
for gene_id, gene_name, ax in zip(
    ['AT5G15840', 'AT1G65480', 'AT2G45660',
     'AT2G22540', 'AT5G10140', 'AT5G01675'],
    ['CO', 'FT', 'SOC1', 'SVP', 'FLC', 'COOLAIR'],
    axes.ravel()):
    plot_single_gene(gene_id, ax, title=gene_name)
plt.tight_layout()
plt.savefig(snakemake.output.ft_plot)
plt.show()
