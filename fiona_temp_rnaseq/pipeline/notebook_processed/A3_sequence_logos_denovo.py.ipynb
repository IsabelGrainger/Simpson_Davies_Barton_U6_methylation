# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/cluster/ggs_lab/mtparker/.conda/envs/snakemake6/lib/python3.10/site-packages', '/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x91\t\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x1bsplicing/denovo/psi_fit.csv\x94\x8c\x17splicing/denovo/psi.csv\x94\x8c:../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x07psi_fit\x94K\x00N\x86\x94\x8c\x03psi\x94K\x01N\x86\x94\x8c\x0fgenome_fasta_fn\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x18\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1e)}\x94\x8c\x05_name\x94h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x10h\nh\x12h\x0bh\x14h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c-figures/splicing/denovo/A3_logos_and_heatmaps\x94a}\x94(h\x0e}\x94\x8c\x0csplice_plots\x94K\x00N\x86\x94sh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh/h,ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0e}\x94h\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x06denovo\x94\x8c\x02A3\x94e}\x94(h\x0e}\x94(\x8c\x08ref_type\x94K\x00N\x86\x94\x8c\nevent_type\x94K\x01N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94b\x8c\x08ref_type\x94hM\x8c\nevent_type\x94hNub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01M\xe8\x03M\xe8\x03\x8c\x13/tmp/381291.1.all.q\x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94\x8c\x07disk_mb\x94K\x03N\x86\x94\x8c\x06tmpdir\x94K\x04N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bhhK\x01hjK\x01hlM\xe8\x03hnM\xe8\x03hpheub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c4notebook_processed/A3_sequence_logos_denovo.py.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x82h\x7fub\x8c\x06config\x94}\x94(\x8c\x0fgenome_fasta_fn\x94\x8c:../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa\x94\x8c\x0cannot_gtf_fn\x94\x8cA../annotations/Araport11_GFF3_genes_transposons.201606.no_chr.gtf\x94\x8c\x16transcriptome_fasta_fn\x94]\x94(\x8c0../annotations/Araport11_genes.201606.cdna.fasta\x94\x8c5../annotations/Araport11_non_coding.201606.cdna.fasta\x94e\x8c\x11proteome_fasta_fn\x94\x8c4../annotations/Araport11_genes.201606.pep.repr.fasta\x94\x8c\x14fastq_screen_genomes\x94}\x94(\x8c\tathaliana\x94\x8c:../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa\x94\x8c\x08hsapiens\x94\x8c=../annotations/Homo_sapiens.GRCh38.dna_sm.primary_assembly.fa\x94\x8c\x07at_rrna\x94\x8c\x1c../annotations/arath_rrna.fa\x94\x8c\x05ecoli\x94\x8c"../annotations/ecoli_k12_mg1655.fa\x94u\x8c\x11suppa_comparisons\x94]\x94(\x8c\x14col0_04c_vs_col0_20c\x94\x8c\x14col0_12c_vs_col0_20c\x94\x8c\x14col0_28c_vs_col0_20c\x94\x8c\x14fio1_04c_vs_fio1_20c\x94\x8c\x14fio1_12c_vs_fio1_20c\x94\x8c\x14fio1_28c_vs_fio1_20c\x94\x8c\x14fio1_04c_vs_col0_04c\x94\x8c\x14fio1_12c_vs_col0_12c\x94\x8c\x14fio1_20c_vs_col0_20c\x94\x8c\x14fio1_28c_vs_col0_28c\x94e\x8c\x0bgene_tracks\x94]\x94(\x8c\tAT5G65050\x94\x8c\tAT1G77080\x94\x8c\tAT5G65060\x94\x8c\tAT1G33410\x94\x8c\tAT4G09980\x94\x8c\tAT3G04910\x94\x8c\tAT3G01150\x94\x8c\tAT1G01060\x94eu\x8c\x04rule\x94\x8c\x1bgenerate_logos_and_heatmaps\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cQ/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/pipeline');
######## snakemake preamble end #########

# %%
import os
import warnings
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
import seaborn as sns
from IPython.display import Markdown, display_markdown

from seqlogo_utils import (
    get_donor_acceptor_seqs_from_df,
    plot_donor_acceptor_logos,
    plot_u5_u6_heatmap,
    calculate_switch_nt,
    perc_seq_pos,
    g_test_seqs,
    A3_CARTOON,
    get_pairwise_seqs,
    g_test_seqs
)

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1.2, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)

# %%
OUTPUT_PATH = snakemake.output.splice_plots
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)

# %%
def display_formatted_markdown(md, **kwargs):
    md_f = md.format(**kwargs)
    display_markdown(Markdown(md_f))

MD_TEXT = open('../rules/notebook_templates/md_text/A3.md').readlines()

ref_type = {'ref': 'reference', 'denovo': '*de novo*'}

display_formatted_markdown(
    '# Alternative 3\'SS analysis using {ref_type} transcriptome assembly',
    ref_type=ref_type[snakemake.wildcards.ref_type]
)
# Out:
# # Alternative 3'SS analysis using *de novo* transcriptome assembly

# %%
def convert_coords(coords):
    if not coords:
        return None
    else:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            return np.fromstring(coords.strip('[] '), sep=' ', dtype=int)

psi_fit = pd.read_csv(
    snakemake.input.psi_fit,
    converters={'chrom': str,
                'alt1': convert_coords,
                'alt2': convert_coords}
)
psi_fit_sig = psi_fit.query(
    'event_class == "A3" & (geno_fdr < 0.05 | gxt_fdr < 0.05)'
)

# %%
a3_pos, a3_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig, snakemake.input.genome_fasta_fn, winsize=6,
)

a3_donors = list(a3_seqs['alt1']['donor'].values())
a3_alt1_acceptors = list(a3_seqs['alt1']['acceptor'].values())
a3_alt2_acceptors = list(a3_seqs['alt2']['acceptor'].values())


display_formatted_markdown(
    MD_TEXT[0],
    num_a3=len(psi_fit_sig),
)

fig = plt.figure(figsize=(15, 5))
donor_logo_ax = plt.subplot2grid((4, 2), (1, 0), rowspan=2)
alt1_logo_ax = plt.subplot2grid((4, 2), (0, 1), rowspan=2)
alt2_logo_ax = plt.subplot2grid((4, 2), (2, 1), rowspan=2)

plot_donor_acceptor_logos(
    a3_donors,
    seq_type='donor',
    title='5\'SS for all fio1-3 sensitive alt. 3\'SS',
    ax=donor_logo_ax
)
plot_donor_acceptor_logos(
    a3_alt1_acceptors,
    seq_type='acceptor',
    title='fio1-3 sensitive 3\'SS',
    ax=alt1_logo_ax
)
plot_donor_acceptor_logos(
    a3_alt2_acceptors,
    seq_type='acceptor',
    title='Alt. 3\'SS increased in fio1-3',
    ax=alt2_logo_ax
)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'a3_fio1_all_logo_heatmap.svg'))
plt.show()

a3_switch = psi_fit_sig.query('event_class == "A3"').apply(calculate_switch_nt, which='a3', axis=1)

display_formatted_markdown(
    MD_TEXT[1],
    a3_5nt=np.mean(a3_switch.abs() <= 6) * 100,
    a3_3nt_exact=np.mean(a3_switch.abs() == 3) * 100,
)

fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(a3_switch, bins=np.arange(-60, 61), align='left')
ax.set_ylabel('Alt 3\'SS pairs')
ax.set_xlabel('Distance between alternative 3\'SS pairs with reduced/increased usage in fio1-3')
plt.savefig(os.path.join(OUTPUT_PATH, 'a3_switch_size_histogram.svg'))
plt.show()
# Out:
# We observed 1484 instances where 3’SS selection was altered in *fio1-3*. In some cases, these alternative 3’SSs were linked with altered 5’SS choice, but this accounted for a relatively small proportion of events. Aggregated motif analysis of all 3’SSs that had either reduced or increased usage in *fio1-3* did not reveal any obvious differences in sequence bias.
# ...

# %%
a3u_pos, a3u_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig.query('event_class == "A3"')[a3_switch < 0],
    snakemake.input.genome_fasta_fn, winsize=6,
)

a3u_donors, a3u_alt1_acceptors, a3u_alt2_acceptors = (
    list(a3u_seqs['alt1']['donor'].values()),
    list(a3u_seqs['alt1']['acceptor'].values()),
    list(a3u_seqs['alt2']['acceptor'].values()),
)

a3d_pos, a3d_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig.query('event_class == "A3"')[a3_switch > 0],
    snakemake.input.genome_fasta_fn, winsize=6,
)

a3d_donors, a3d_alt1_acceptors, a3d_alt2_acceptors = (
    list(a3d_seqs['alt1']['donor'].values()),
    list(a3d_seqs['alt1']['acceptor'].values()),
    list(a3d_seqs['alt2']['acceptor'].values()),
)

display_formatted_markdown(
    MD_TEXT[2],
    a3u_perc_a4=perc_seq_pos(a3u_donors, 4, 'A')[1],
    a3u_perc_d3c=perc_seq_pos(a3u_alt1_acceptors, -2, 'C')[1], # -2 because perc_seq_pos was written for donors not acceptors so there is an off by one error
    a3u_perc_u3c=perc_seq_pos(a3u_alt2_acceptors, -2, 'C')[1],
)
display_formatted_markdown(
    MD_TEXT[3],
    a3d_perc_a4=perc_seq_pos(a3d_donors, 4, 'A')[1],
    a3d_perc_u4=perc_seq_pos(a3d_donors, 4, 'U')[1],
)

fig = plt.figure(figsize=(20, 7))
a3u_donor_logo_ax = plt.subplot2grid((3, 3), (0, 0))
a3u_ups_logo_ax = plt.subplot2grid((3, 3), (0, 1))
a3u_dwn_logo_ax = plt.subplot2grid((3, 3), (0, 2))
cartoon_ax = plt.subplot2grid((3, 3), (1, 0), colspan=3)
a3d_donor_logo_ax = plt.subplot2grid((3, 3), (2, 0))
a3d_ups_logo_ax = plt.subplot2grid((3, 3), (2, 1))
a3d_dwn_logo_ax = plt.subplot2grid((3, 3), (2, 2))


# plot_cartoon in centre
cartoon_ax.set_axis_off()
cartoon_ax.imshow(A3_CARTOON)

plot_donor_acceptor_logos(
    a3u_donors,
    seq_type='donor',
    ax=a3u_donor_logo_ax,
    title=''
)
plot_donor_acceptor_logos(
    a3u_alt2_acceptors,
    seq_type='acceptor',
    ax=a3u_ups_logo_ax,
    title=''
)
plot_donor_acceptor_logos(
    a3u_alt1_acceptors,
    seq_type='acceptor',
    ax=a3u_dwn_logo_ax,
    title=''
)
a3u_donor_logo_ax.text(
    .5, 0.93,
    f'Alt. 3\'SSs with increased upstream use in fio1-3',
    transform=fig.transFigure,
    horizontalalignment='center'
)


plot_donor_acceptor_logos(
    a3d_donors,
    seq_type='donor',
    ax=a3d_donor_logo_ax,
    title=''
)
plot_donor_acceptor_logos(
    a3d_alt1_acceptors,
    seq_type='acceptor',
    ax=a3d_ups_logo_ax,
    title=''
)
plot_donor_acceptor_logos(
    a3d_alt2_acceptors,
    seq_type='acceptor',
    ax=a3d_dwn_logo_ax,
    title=''
)
a3d_donor_logo_ax.text(
    .5, 0.03,
    f'Alt. 3\'SSs with increased downstream use in fio1-3',
    transform=fig.transFigure,
    horizontalalignment='center'
)
plt.savefig(os.path.join(OUTPUT_PATH, 'a3_fio1_logo.svg'))
plt.show()
# Out:
# Since 3’SS choice can occur by scanning from the branchpoint to the first available 3’SS motif downstream, selection of a more upstream or downstream 3’SS probably results from either a change in branchpoint or 3’SS motif preference. We therefore separated examples shifting to more upstream and downstream 3’SSs in *fio1-3* and performed motif analysis. At introns where a more upstream 3’SS was preferred in *fio1-3*, we found that 80.5% of the corresponding 5’SSs were characterised by A+4. In these cases, 68.0% of the downstream 3’SSs with reduced usage in *fio1-3* had C—3, compared to only 30.2% of upstream 3’SSs.
# ...

# %%
# plot background rate of sequence motifs at upstream/downstream 3'SSs

psi_fit_a3 = psi_fit.query('event_class == "A3"')
all_a3_switch = psi_fit_a3.apply(calculate_switch_nt, which='a3', axis=1)

all_a3_pos, all_a3_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_a3, snakemake.input.genome_fasta_fn, winsize=6,
)

a3_upstream_seqs = []
a3_downstream_seqs = []
for alt1, alt2, sw in zip(*get_pairwise_seqs(all_a3_pos, all_a3_seqs, which='acceptor'),
                          all_a3_switch.values):
    if sw > 0:
        a3_upstream_seqs.append(alt1)
        a3_downstream_seqs.append(alt2)
    else:
        a3_upstream_seqs.append(alt2)
        a3_downstream_seqs.append(alt1)

fig, axes = plt.subplots(figsize=(7, 5), nrows=2)        

plot_donor_acceptor_logos(
    a3_upstream_seqs,
    seq_type='acceptor',
    title='Upstream 3\'SS',
    ax=axes[0],
)
plot_donor_acceptor_logos(
    a3_downstream_seqs,
    seq_type='acceptor',
    title='Downstream 3\'SS',
    ax=axes[1],
)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'a3_background_upstream_downstream.svg'))
plt.show()

# %%
a3_pos, a3_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig, snakemake.input.genome_fasta_fn, winsize=6,
)

psi_fit_sig['donor_p4'] = [a3_seqs['alt1']['donor'][idx][9] for idx in a3_pos['alt1']['donor']]
psi_fit_sig['donor_p4'] = psi_fit_sig['donor_p4'].map({'A': 'A', 'U': 'U', 'G': 'S', 'C': 'S'})
psi_fit_sig['acceptor_n3_equal'] = [a1[3] == a2[3] for a1, a2, in zip(*get_pairwise_seqs(a3_pos, a3_seqs, which='acceptor'))]
psi_fit_sig['acceptor_n3_equal'] = psi_fit_sig['acceptor_n3_equal'].map({True: 'Same', False: 'Different'})
psi_fit_sig['downstream_dpsi'] = [dpsi if sw > 0 else -dpsi for dpsi, sw in zip(psi_fit_sig.dpsi, a3_switch)]

fig, ax = plt.subplots(figsize=(5, 5))
sns.boxplot(
    x='donor_p4',
    y='downstream_dpsi',
    hue='acceptor_n3_equal',
    order=['A', 'U', 'S'],
    hue_order=['Same', 'Different'],
    data=psi_fit_sig,
    showfliers=False
)
ax.axhline(0, ls='--', color='#252525', zorder=-1)
ax.set_ylabel('Change in use of downstream 3\'SS (ΔPSI)')
ax.set_xlabel('5\'SS +4 base')
ax.legend(title='Alt. 3\'SS pair —3 bases',loc=4, ncol=2)
plt.savefig(os.path.join(OUTPUT_PATH, 'a3_order_vs_motif_boxplot.svg'))
plt.show()
# Out:
# /cluster/ggs_lab/mtparker/snakemake_conda_envs/envs/6cf524805240fb04c52d0d93c21d8c77/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /cluster/ggs_lab/mtparker/snakemake_conda_envs/envs/6cf524805240fb04c52d0d93c21d8c77/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
