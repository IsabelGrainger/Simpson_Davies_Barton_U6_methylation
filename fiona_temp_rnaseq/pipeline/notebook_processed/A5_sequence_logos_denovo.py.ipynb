# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/cluster/ggs_lab/mtparker/.conda/envs/snakemake6/lib/python3.10/site-packages', '/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95h\t\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x1bsplicing/denovo/psi_fit.csv\x94\x8c:../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x07psi_fit\x94K\x00N\x86\x94\x8c\x0fgenome_fasta_fn\x94K\x01N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x15\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1b)}\x94\x8c\x05_name\x94h\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh\x0fh\nh\x11h\x0bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c-figures/splicing/denovo/A5_logos_and_heatmaps\x94a}\x94(h\r}\x94\x8c\x0csplice_plots\x94K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh,h)ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\r}\x94h\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x06denovo\x94\x8c\x02A5\x94e}\x94(h\r}\x94(\x8c\x08ref_type\x94K\x00N\x86\x94\x8c\nevent_type\x94K\x01N\x86\x94uh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94b\x8c\x08ref_type\x94hJ\x8c\nevent_type\x94hKub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01M\xe8\x03M\xe8\x03\x8c\x13/tmp/375602.1.all.q\x94e}\x94(h\r}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94\x8c\x07disk_mb\x94K\x03N\x86\x94\x8c\x06tmpdir\x94K\x04N\x86\x94uh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bheK\x01hgK\x01hiM\xe8\x03hkM\xe8\x03hmhbub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c4notebook_processed/A5_sequence_logos_denovo.py.ipynb\x94a}\x94(h\r}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh\x7fh|ub\x8c\x06config\x94}\x94(\x8c\x0fgenome_fasta_fn\x94\x8c:../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa\x94\x8c\x0cannot_gtf_fn\x94\x8cA../annotations/Araport11_GFF3_genes_transposons.201606.no_chr.gtf\x94\x8c\x16transcriptome_fasta_fn\x94]\x94(\x8c0../annotations/Araport11_genes.201606.cdna.fasta\x94\x8c5../annotations/Araport11_non_coding.201606.cdna.fasta\x94e\x8c\x11proteome_fasta_fn\x94\x8c4../annotations/Araport11_genes.201606.pep.repr.fasta\x94\x8c\x14fastq_screen_genomes\x94}\x94(\x8c\tathaliana\x94\x8c:../annotations/Arabidopsis_thaliana.TAIR10.dna.toplevel.fa\x94\x8c\x08hsapiens\x94\x8c=../annotations/Homo_sapiens.GRCh38.dna_sm.primary_assembly.fa\x94\x8c\x07at_rrna\x94\x8c\x1c../annotations/arath_rrna.fa\x94\x8c\x05ecoli\x94\x8c"../annotations/ecoli_k12_mg1655.fa\x94u\x8c\x11suppa_comparisons\x94]\x94(\x8c\x14col0_04c_vs_col0_20c\x94\x8c\x14col0_12c_vs_col0_20c\x94\x8c\x14col0_28c_vs_col0_20c\x94\x8c\x14fio1_04c_vs_fio1_20c\x94\x8c\x14fio1_12c_vs_fio1_20c\x94\x8c\x14fio1_28c_vs_fio1_20c\x94\x8c\x14fio1_04c_vs_col0_04c\x94\x8c\x14fio1_12c_vs_col0_12c\x94\x8c\x14fio1_20c_vs_col0_20c\x94\x8c\x14fio1_28c_vs_col0_28c\x94e\x8c\x0bgene_tracks\x94]\x94(\x8c\tAT5G65050\x94\x8c\tAT1G77080\x94\x8c\tAT5G65060\x94\x8c\tAT1G33410\x94\x8c\tAT4G09980\x94\x8c\tAT3G04910\x94\x8c\tAT3G01150\x94\x8c\tAT1G01060\x94eu\x8c\x04rule\x94\x8c\x1bgenerate_logos_and_heatmaps\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cQ/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/cluster/ggs_lab/mtparker/papers/fiona/fiona_temp_rnaseq/pipeline');
######## snakemake preamble end #########

# %%
import os
import warnings
import itertools as it
from functools import partial
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
import seaborn as sns
from IPython.display import Markdown, display_markdown

from seqlogo_utils import (
    iupac_classify,
    u5_classify,
    get_donor_acceptor_seqs_from_df,
    plot_donor_acceptor_logos,
    plot_u5_u6_heatmap,
    calculate_switch_nt,
    perc_seq_pos,
    perc_seq_switch_pos,
    get_pairwise_seqs,
    g_test_seqs,
)

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1.2, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)

# %%
OUTPUT_PATH = snakemake.output.splice_plots
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)

# %%
def display_formatted_markdown(md, **kwargs):
    md_f = md.format(**kwargs)
    display_markdown(Markdown(md_f))

MD_TEXT = open('../rules/notebook_templates/md_text/A5.md').readlines()

ref_type = {'ref': 'reference', 'denovo': '*de novo*'}

display_formatted_markdown(
    '# Alternative 5\'SS analysis using {ref_type} transcriptome assembly',
    ref_type=ref_type[snakemake.wildcards.ref_type]
)
# Out:
# # Alternative 5'SS analysis using *de novo* transcriptome assembly

# %%
def convert_coords(coords):
    if not coords:
        return None
    else:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            return np.fromstring(coords.strip('[] '), sep=' ', dtype=int)

psi_fit = pd.read_csv(
    snakemake.input.psi_fit,
    converters={'chrom': str,
                'alt1': convert_coords,
                'alt2': convert_coords}
)
psi_fit_sig = psi_fit.query(
    'event_class == "A5" & (geno_fdr < 0.05 | gxt_fdr < 0.05)'
)

# %%
donor_acceptor_pos, donor_acceptor_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig, snakemake.input.genome_fasta_fn, winsize=6
)

# %%
a5_pos, a5_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig, snakemake.input.genome_fasta_fn, winsize=6
)

a5_alt1_donors, a5_alt1_acceptors, a5_alt2_donors, a5_alt2_acceptors = (
    list(a5_seqs['alt1']['donor'].values()),
    list(a5_seqs['alt1']['acceptor'].values()),
    list(a5_seqs['alt2']['donor'].values()),
    list(a5_seqs['alt2']['acceptor'].values()),
)

display_formatted_markdown(
    MD_TEXT[0],
    num_a5=len(psi_fit_sig),
    g_test_p=g_test_seqs(*get_pairwise_seqs(a5_pos, a5_seqs, 'donor'))[1],
)

fig = plt.figure(figsize=(15, 7))
alt1_logo_ax = plt.subplot2grid((3, 2), (0, 0))
alt1_hmap_ax = plt.subplot2grid((3, 2), (1, 0), rowspan=2)
alt2_logo_ax = plt.subplot2grid((3, 2), (0, 1))
alt2_hmap_ax = plt.subplot2grid((3, 2), (1, 1), rowspan=2)

plot_donor_acceptor_logos(
    a5_alt1_donors,
    seq_type='donor',
    title='fio1-3 sensitive 5\'SS',
    ax=alt1_logo_ax
)
_, a5_alt1_u5_grp, a5_alt1_u6_grp = plot_u5_u6_heatmap(a5_alt1_donors, vmin=0, vmax=616, ax=alt1_hmap_ax)

plot_donor_acceptor_logos(
    a5_alt2_donors,
    seq_type='donor',
    title='Alt. 5\'SS increased in fio1-3',
    ax=alt2_logo_ax
)
_, a5_alt2_u5_grp, a5_alt2_u6_grp = plot_u5_u6_heatmap(a5_alt2_donors, vmin=0, vmax=616, ax=alt2_hmap_ax)
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_fio1_logo.svg'))
plt.show()
# Out:
# We identified 2369 changes in 5’SS choice caused by loss of FIO1 function. We asked if differences in cis-element features could account for FIO1-dependent 5’SS selection. Comparing 5’SSs that exhibited reduced selection in *fio1-3*, and their corresponding alternative 5’SSs, which were more frequently selected in *fio1-3*, we found that there was a significant difference in base composition at the —2 to +5 positions (G-test p = 0). Specifically, we identified a //GURAG motif (R = A or G) at 5’SSs sensitive to the loss of FIO1 function. This motif is consistent with recognition by the U6 snRNA ACAGA box. In contrast, the alternative 5’SSs selected more frequently in *fio1-3* mutants were characterised by an AG//GU motif. This motif is consistent with U5 snRNA loop 1 recognition of the upstream exon sequences. A heat map of the sequence composition of fio1-3-sensitive 5’SSs reveals that they are more likely to be characterised by strong base-pairing matches to the U6 snRNA ACAGA box, 
# ...

# %%
# +4 position A vs not A contigency table
a4 = np.array([g[1] for g in a5_alt1_u6_grp + a5_alt2_u6_grp])
y = np.repeat([1, 0], [len(a5_alt1_u6_grp), len(a5_alt2_u6_grp)])

display_formatted_markdown(
    MD_TEXT[1],
    a4_acc=100 - np.mean((a4 == 'A')  ^ (y == 1)) * 100
)

fig, ax = plt.subplots(figsize=(3, 3))
sns.heatmap(
    pd.crosstab(y, a4),
    ax=ax,
    cmap='Blues',
    square=True,
    cbar=False,
    annot=True,
    fmt='d'
)
ax.set_xlabel('Base at +4 position')
ax.set_yticklabels(['Increase', 'Decrease'], va='center')
ax.set_ylabel('ΔPSI in fio1-3')
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_u6_contigency_table_p4.svg'))
plt.show()
# Out:
# Remarkably, the presence or absence of an A at the +4 position (A+4) correctly separates 78.6% of the 5’SSs exhibiting decreased and increased usage in *fio1-3*. In humans, where pairing of the 5’SS to U6 occurs before activation of the spliceosome, the 5’SS A+4 faces the m6A of the U6 snRNA ACm6AGA box in the B complex before docking of the 5’SS in the active site.

# %%
# full contingency table for +4 position
a5_alt1_pairwise, a5_alt2_pairwise = get_pairwise_seqs(a5_pos, a5_seqs)
a4_alt1 = np.array([g[9] for g in a5_alt1_pairwise])
a4_alt2 = np.array([g[9] for g in a5_alt2_pairwise])

ab_mask = perc_seq_switch_pos(a5_alt1_pairwise, a5_alt2_pairwise, 4, 'A', 'B')[0]
display_formatted_markdown(
    MD_TEXT[2],
    a5_perc_u4=perc_seq_pos(a5_alt2_donors, 4, 'U')[1],
    a5_perc_ab4=perc_seq_switch_pos(a5_alt1_pairwise, a5_alt2_pairwise, 4, 'A', 'B')[1],
    a5_perc_au4=perc_seq_pos(
        [s for s, m in zip(a5_alt2_pairwise, ab_mask) if m],
        4, 'U'
    )[1],
    a5_perc_ba4=perc_seq_switch_pos(a5_alt1_pairwise, a5_alt2_pairwise, 4, 'B', 'A')[1],
    a5_perc_su4=perc_seq_switch_pos(a5_alt1_pairwise, a5_alt2_pairwise, 4, 'S', 'U')[1],
    a5_perc_nn4=np.mean(a4_alt1 == a4_alt2) * 100
)

fig, axes = plt.subplots(figsize=(10, 5), ncols=2)
sns.heatmap(
    pd.crosstab(a4_alt2, a4_alt1),
    ax=axes[0],
    cmap='Blues',
    square=True,
    cbar=False,
    annot=True,
    fmt='d'
)
axes[0].set_xlabel('Base at +4 position in reduced site')
axes[0].set_ylabel('Base at +4 position in increased site')

# -1/+5 contigency table for 5'SS pairs with equivalent +4 positions

mask = [a1 == a2 for a1, a2 in zip(a4_alt1, a4_alt2)]
is_g = partial(iupac_classify, consensus='G')
masked_alt1_m1p5 = [f'{is_g(seq[5])}/{is_g(seq[10])}' for seq, m
                    in zip(a5_alt1_pairwise, mask) if m]
masked_alt2_m1p5 = [f'{is_g(seq[5])}/{is_g(seq[10])}' for seq, m
                    in zip(a5_alt2_pairwise, mask) if m]


contingency_table = pd.crosstab(
        pd.Series(masked_alt2_m1p5, name='Increased 5\'SS -1/+5 base'),
        pd.Series(masked_alt1_m1p5, name='Reduced 5\'SS -1/+5 base'),
)
contingency_table = contingency_table.loc[
    ('H/G', 'H/H', 'G/G', 'G/H'),
    ('H/G', 'G/G', 'H/H', 'G/H'),
]

sns.heatmap(
    contingency_table,
    ax=axes[1],
    cmap='Blues',
    square=True,
    cbar=False,
    annot=True,
    fmt='d'
)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_u6_contigency_table_full.svg'))
plt.show()
# Out:
# Of the 5’SSs with increased usage in *fio1-3*, 48.2% have U+4, which could make a Watson-Crick base pair with the corresponding unmethylated residue of U6 snRNA. In total, 61.8% of 5’SS changes in *fio1-3* are associated with a switch from A+4 to B+4 (A→B+4), of which 58.8% were A→U+4. In comparison, only 3.8% of alternative 5’SS pairs are reciprocal B→A+4 switches, indicating that this shift is strongly directional. A further 8.0% of alternative 5’SS pairs are S→U+4, suggesting that a Watson Crick A-U base-pair is favoured when U6 snRNA is not m6A modified. Surprisingly, 22.3% of alternative 5’SS pairs have no difference in base at the +4 position. However, of these 5’SS pairs, the majority are associated with a G→H+5 and/or H→G–1 switch that weakens interactions with the U6 snRNA ACAGA box and strengthens U5 snRNA loop 1 interactions.

# %%
def plot_paired_base_effect_size(alt1_seqs, alt2_seqs, pos, dpsi,
                                 order, pal, iupac_filt,
                                 ax=None):
    # convert 5'SS pos to index
    i = len(alt1_seqs[0]) // 2 + pos - 1
    alt1_base = [iupac_filt[seq[i]] for seq in alt1_seqs]
    alt2_base = [iupac_filt[seq[i]] for seq in alt2_seqs]
    base_grp = [f'{a1}/{a2}' for a1, a2 in zip(alt1_base, alt2_base)]

    mirrored_order = ['/'.join(o) for o in (it.product(order, order[::-1]))]
    if ax is None:
        fig, ax = plt.subplots(figsize=(len(mirrored_order) / 1.5, 4))
    sns.boxplot(
        x=base_grp,
        y=dpsi,
        showfliers=False,
        order=mirrored_order,
        palette=[pal[o[0]] for o in mirrored_order],
        ax=ax
    )
    ax.set_xlabel(f'{pos:+} base of fio1-3 sensitive/\nalternative 5\'SS')
    ax.set_ylabel('Effect size (absolute ΔPSI)')
    return ax

display_formatted_markdown(
    MD_TEXT[3]
)

fig = plt.figure(figsize=(11, 5))
p4_ax = plt.subplot2grid((1, 10), (0, 0), colspan=6)
p5_ax = plt.subplot2grid((1, 10), (0, 6), colspan=4, sharey=p4_ax)

plot_paired_base_effect_size(
    a5_alt1_pairwise, a5_alt2_pairwise, 4,
    psi_fit_sig.dpsi,
    order='ASU',
    pal={'A': pal[2], 'S': '#888888', 'U': pal[1]},
    iupac_filt={'A': 'A', 'U': 'U', 'G': 'S', 'C': 'S'},
    ax=p4_ax
)

plot_paired_base_effect_size(
    a5_alt1_pairwise, a5_alt2_pairwise, 5,
    psi_fit_sig.dpsi,
    order='GH',
    pal={'H': '#888888', 'G': pal[3]},
    iupac_filt={'A': 'H', 'U': 'H', 'G': 'G', 'C': 'H'},
    ax=p5_ax
)
p4_ax.set_ylim(0, 0.5)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_u6_base_effect_size.svg'))
plt.show()

display_formatted_markdown(
    MD_TEXT[4]
)

order = ['AG', 'BG', 'AH', 'BH']
fig, ax = plt.subplots(figsize=(4, 4))
sns.boxplot(
    x=[u5_classify(s) for s in a5_alt1_pairwise],
    y=psi_fit_sig.dpsi,
    showfliers=False,
    order=order,
    color=pal[0]
)
ax.set_ylim(0, 0.5)
ax.set_xlabel('U5 class of fio1-3 sensitive 5\'SS')
ax.set_ylabel('Effect size (absolute ΔPSI)')
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_u5_class_effect_size.svg'))
plt.show()
# Out:
# To investigate the statistically significant FIO1-dependent switches in 5’SS preference further, we interrogated the effect size (absolute ΔPSI). The largest effect sizes were associated with A→U+4. In contrast, alternative 5’SS pairs where there was an A+4→A shift had smaller effect sizes. In addition, we found that fio1-3-sensitive 5’SSs with 5’SS G+5 have larger effect sizes, but that G+5 at the alternative 5’SS has no effect, suggesting that G+5 is only deleterious in *fio1-3* when in combination with A+4.
# Finally, we found that *fio1-3*-sensitive 5’SSs with AG//GU motifs had smaller effect sizes, indicating that stronger matches to U5 snRNA loop 1 are able to suppress the effect of unfavourable U6 snRNA interactions in *fio1-3*.

# %%
a5_switch = psi_fit_sig.apply(calculate_switch_nt, axis=1)

display_formatted_markdown(
    MD_TEXT[5]
)

fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(a5_switch, bins=np.arange(-80, 81), align='left')
ax.set_ylabel('Alt5\'SS pairs')
ax.set_xlabel('Distance between alternative 5\'SS pairs with reduced/increased usage in fio1-3')
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_switch_size_histogram.svg'))
plt.show()

_, a5_temp_seqs = get_donor_acceptor_seqs_from_df(
    psi_fit_sig[a5_switch == 5],
    snakemake.input.genome_fasta_fn, winsize=7
)
plot_donor_acceptor_logos(
    [s[:12] for s in a5_temp_seqs['alt2']['donor'].values()],
    seq_type=None,
    title='Alt 5\'SS pairs with switch distance of +5'
)
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_5nt_switch_logo.svg'))
plt.show()
# Out:
# We next asked whether there was directionality to shifts in splice site choice in *fio1-3*. Alternative 5’SSs were almost equally likely to be selected either upstream or downstream. We detected many examples of 5’SS shifts of exactly -4 nt, +4 nt, and +5 nt. Notably, in +5 nt switches, 5’SSs with the strong U6 snRNA ACAGA recognition sequence //GURAGGU can become strong U5 snRNA loop 1 5’SSs with the sequence GURAG//GU, suggesting that overlaps in the registers of consensus sequences for U5 and U6 snRNA interactions could facilitate alternative splicing.

# %% [markdown]
# ## Temperature alt 5'SS

# %%
a5_temp_pos_1, a5_temp_seqs_1 = get_donor_acceptor_seqs_from_df(
    psi_fit.query('event_class == "A5" & (temp_fdr < 0.05 | txt_fdr < 0.05) & dpsi2 < 0'),
    snakemake.input.genome_fasta_fn, winsize=6
)
a5_temp_pos_2, a5_temp_seqs_2 = get_donor_acceptor_seqs_from_df(
    psi_fit.query('event_class == "A5" & (temp_fdr < 0.05 | txt_fdr < 0.05) & dpsi2 > 0'),
    snakemake.input.genome_fasta_fn, winsize=6
)
# merge pos and neg dpsis
a5_temp_pos = {
    'alt1': {'donor': a5_temp_pos_1['alt1']['donor'] + a5_temp_pos_2['alt2']['donor']},
    'alt2': {'donor': a5_temp_pos_1['alt2']['donor'] + a5_temp_pos_2['alt1']['donor']},
}
a5_temp_seqs = {
    'alt1': {'donor': {**a5_temp_seqs_1['alt1']['donor'], **a5_temp_seqs_2['alt2']['donor']}},
    'alt2': {'donor': {**a5_temp_seqs_1['alt2']['donor'], **a5_temp_seqs_2['alt1']['donor']}},
}
cold_a5_donors = list(a5_temp_seqs['alt1']['donor'].values())
hot_a5_donors = list(a5_temp_seqs['alt2']['donor'].values())

display_formatted_markdown(
    MD_TEXT[6],
    g_test_p=g_test_seqs(*get_pairwise_seqs(a5_temp_pos, a5_temp_seqs))[1]
)

fig = plt.figure(figsize=(15, 7))
cold_logo_ax = plt.subplot2grid((3, 2), (0, 0))
cold_hmap_ax = plt.subplot2grid((3, 2), (1, 0), rowspan=2)
hot_logo_ax = plt.subplot2grid((3, 2), (0, 1))
hot_hmap_ax = plt.subplot2grid((3, 2), (1, 1), rowspan=2)


plot_donor_acceptor_logos(
    cold_a5_donors,
    seq_type='donor',
    title='Alt. 5\'SS used more at low temperature',
    ax=cold_logo_ax
)
plot_u5_u6_heatmap(cold_a5_donors, ax=cold_hmap_ax, vmin=0, vmax=139)
plot_donor_acceptor_logos(
    hot_a5_donors,
    seq_type='donor',
    title='Alt. 5\'SS used more at high temperature',
    ax=hot_logo_ax
)
plot_u5_u6_heatmap(hot_a5_donors, ax=hot_hmap_ax, vmin=0, vmax=139)
plt.savefig(os.path.join(OUTPUT_PATH, 'a5_temp_logo_heatmap.svg'))
plt.show()
# Out:
# We analysed the temperature-dependent shifts in splice site choice in the Col-0 RNA-Seq data as a control. In contrast to the clear difference in sequence composition of 5’SSs with altered use in *fio1-3*, there was no significant difference between the positional base frequencies for 5’SSs that were used preferentially at lower and elevated temperatures in Col-0 (G-test p = 0.28). We conclude that the features of 5’SSs sensitive to loss of FIO1 are specific, and not a generic feature of disrupted splicing patterns.
